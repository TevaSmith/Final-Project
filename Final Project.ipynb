# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Teva Smith**

# %% [markdown]
# *I am interested in data science because the ability to shape and mold the world around you is amazing*

# %% [markdown]
# ### The next cell will calculate 7 plus 7

# %%
a = 7
a = a+a
print("the Value of 7 + 7 is",a)
# Out:
# the Value of 7 + 7 is 14

# %% [markdown]
# ***
# * Bullet List Item 01
# * Bullet List Item 02
# * Bullet List Item 03
# 1. Numbered List Item 01
# 2. Numbered List Item 02
# 3. Numbered List Item 03
# | Column 01 | Column 02 | Column 03 | Column 04 | Column 05 |
# |-----------|-----------|-----------|-----------|-----------|
# | HI | How | are | you | doing |
# | I'm | Well | Thanks | For | Asking |
